# %%
# !pip install torch_geometric torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.9.0+cu126.html
# Out:
# Looking in links: https://data.pyg.org/whl/torch-2.9.0+cu126.html
# Collecting torch_geometric
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 5.7 MB/s eta 0:00:00
# Collecting torch_scatter
#   Downloading https://data.pyg.org/whl/torch-2.9.0%2Bcu126/torch_scatter-2.1.2%2Bpt29cu126-cp312-cp312-linux_x86_64.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/10.9 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/10.9 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/10.9 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/10.9 MB 227.2 kB/s eta 0:00:48
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/10.9 MB 227.2 kB/s eta 0:00:48
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/10.9 MB 227.2 kB/s eta 0:00:48
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.1/10.9 MB 298.9 kB/s eta 0:00:37
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.1/10.9 MB 298.9 kB/s eta 0:00:37
#      ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.2/10.9 MB 471.1 kB/s eta 0:00:23
#      ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.2/10.9 MB 471.1 kB/s eta 0:00:23
#      ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.2/10.9 MB 471.1 kB/s eta 0:00:23
#      ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.4/10.9 MB 778.7 kB/s eta 0:00:14
#      ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.4/10.9 MB 778.7 kB/s eta 0:00:14
#      ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.4/10.9 MB 778.7 kB/s eta 0:00:14
#      ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.9/10.9 MB 1.3 MB/s eta 0:00:08
#      ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.9/10.9 MB 1.3 MB/s eta 0:00:08
#      ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.9/10.9 MB 1.3 MB/s eta 0:00:08
#      ━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/10.9 MB 2.2 MB/s eta 0:00:05
#      ━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/10.9 MB 2.2 MB/s eta 0:00:05
#      ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/10.9 MB 3.7 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/10.9 MB 3.7 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/10.9 MB 3.7 MB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━ 6.2/10.9 MB 5.5 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 7.3/10.9 MB 6.5 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━ 7.3/10.9 MB 6.5 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━ 10.1/10.9 MB 8.0 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 16.3 MB/s eta 0:00:00
# Collecting torch_sparse
#   Downloading https://data.pyg.org/whl/torch-2.9.0%2Bcu126/torch_sparse-0.6.18%2Bpt29cu126-cp312-cp312-linux_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/5.3 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 109.4 MB/s eta 0:00:00
# Collecting torch_cluster
#   Downloading https://data.pyg.org/whl/torch-2.9.0%2Bcu126/torch_cluster-1.6.3%2Bpt29cu126-cp312-cp312-linux_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/3.5 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 91.6 MB/s eta 0:00:00
# Collecting torch_spline_conv
#   Downloading https://data.pyg.org/whl/torch-2.9.0%2Bcu126/torch_spline_conv-1.2.2%2Bpt29cu126-cp312-cp312-linux_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.1 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.1 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.1 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.1 MB ? eta -:--:--
#      ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.1 MB 220.9 kB/s eta 0:00:05
#      ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.1 MB 220.9 kB/s eta 0:00:05
#      ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.1/1.1 MB 300.5 kB/s eta 0:00:04
#      ━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.1/1.1 MB 300.5 kB/s eta 0:00:04
#      ━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.2/1.1 MB 472.3 kB/s eta 0:00:02
#      ━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.2/1.1 MB 472.3 kB/s eta 0:00:02
#      ━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.2/1.1 MB 472.3 kB/s eta 0:00:02
#      ━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━ 0.4/1.1 MB 781.2 kB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━ 0.4/1.1 MB 781.2 kB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━ 0.4/1.1 MB 781.2 kB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━ 0.9/1.1 MB 1.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━ 0.9/1.1 MB 1.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━ 0.9/1.1 MB 1.3 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.13.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2025.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.6.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from torch_sparse) (1.16.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch_geometric) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (2026.1.4)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->torch_geometric) (4.15.0)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.3 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.6 MB/s eta 0:00:00
# Installing collected packages: torch_spline_conv, torch_scatter, torch_sparse, torch_cluster, torch_geometric
# Successfully installed torch_cluster-1.6.3+pt29cu126 torch_geometric-2.7.0 torch_scatter-2.1.2+pt29cu126 torch_sparse-0.6.18+pt29cu126 torch_spline_conv-1.2.2+pt29cu126

# %%
import torch
import optuna
import torch.nn as nn
import torch.nn.functional as F
import json

from torch_geometric.loader import DataLoader
from torch_geometric.nn import GPSConv, GINConv, global_add_pool
from torch_geometric.transforms import AddLaplacianEigenvectorPE
from sklearn import metrics

# %%
class GPS(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout, num_heads, pe_dim):
        """
        GPSConv model with LaplacianPE.

        pe_dim: number of Laplacian eigenvectors (fixed at PE_DIM=5).
        """
        super().__init__()
        self.dropout = dropout
        self.pe_dim = pe_dim

        # Projects the first pe_dim eigenvectors into hidden_dim
        self.pe_encoder = nn.Linear(pe_dim, hidden_dim)

        # Brings raw node features up to hidden_dim before GPS layers
        self.input_encoder = nn.Linear(input_dim, hidden_dim)

        # GPS layers: each wraps a local GINConv + global MultiheadAttention
        self.convs = nn.ModuleList()
        for _ in range(num_layers):
            gin_mlp = nn.Sequential(
                nn.Linear(hidden_dim, hidden_dim),
                nn.BatchNorm1d(hidden_dim),
                nn.ReLU(),
                nn.Linear(hidden_dim, hidden_dim),
            )
            self.convs.append(
                GPSConv(
                    channels=hidden_dim,
                    conv=GINConv(gin_mlp),
                    heads=num_heads,
                    dropout=dropout,
                    attn_type="multihead",
                )
            )

        self.lin1 = nn.Linear(hidden_dim, hidden_dim)
        self.classifier = nn.Linear(hidden_dim, 1)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch

        pe = data.laplacian_eigenvector_pe
        x = self.input_encoder(x) + self.pe_encoder(pe)

        # GPS layers with jumping-knowledge sum over layers
        h_graph = 0
        for conv in self.convs:
            x = conv(x, edge_index, batch)
            x = F.dropout(x, self.dropout, training=self.training)
            h_graph = h_graph + global_add_pool(x, batch)

        h = F.relu(self.lin1(h_graph))
        h = F.dropout(h, self.dropout, training=self.training)
        return self.classifier(h).view(-1)

# %%
# ── Dataset loading ────────────────────────────────────────────────────────
# pe_dim=5 is fixed: safe for graphs with as few as 8 nodes (bound is 7)
# and sufficient to capture the relevant structural signal.
PE_DIM = 5
pe_transform = AddLaplacianEigenvectorPE(
    k=PE_DIM,
    attr_name="laplacian_eigenvector_pe",
    is_undirected=True,
)

train_dataset_raw = torch.load(
    "/kaggle/input/datasets/samuelvarchol/graphs-with-autgrpg-1/train_dataset_baseline.pt",
    weights_only=False,
)
val_dataset_raw = torch.load(
    "/kaggle/input/datasets/samuelvarchol/graphs-with-autgrpg-1/val_dataset.pt",
    weights_only=False,
)

print("Applying LaplacianPE transform to train set...")
train_dataset = [pe_transform(data) for data in train_dataset_raw]
print("Applying LaplacianPE transform to val set...")
val_dataset   = [pe_transform(data) for data in val_dataset_raw]
print(f"Done. PE shape per node: {train_dataset[0].laplacian_eigenvector_pe.shape}  (fixed pe_dim={PE_DIM})")

number_of_features = train_dataset[0].num_node_features
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device} | Node features: {number_of_features}")
# Out:
# Applying LaplacianPE transform to train set...
# Applying LaplacianPE transform to val set...
# Done. PE shape per node: torch.Size([13, 5])  (fixed pe_dim=5)
# Device: cuda | Node features: 3

# %%
def train():
    model.train()
    total_loss = 0

    for data in train_loader:
        data = data.to(device)
        out = model(data)
        loss = criterion(out, data.y.float())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * data.num_graphs

    return total_loss / len(train_loader.dataset)


@torch.no_grad()
def test(loader):
    model.eval()
    predictions = []
    labels = []

    for data in loader:
        data = data.to(device)
        out = model(data)
        pred = (out > 0).float()
        predictions.append(pred.cpu())
        labels.append(data.y.cpu())

    accuracy = metrics.accuracy_score(torch.cat(labels), torch.cat(predictions))
    f1 = metrics.f1_score(torch.cat(labels), torch.cat(predictions))

    return accuracy, f1

# %%
def objective(trial: optuna.Trial):
    global model, optimizer, criterion, scheduler, train_loader, val_loader

    # ── Hyperparameters ───────────────────────────────────────────────────
    hidden_dim   = trial.suggest_categorical("hidden_dim", [64, 128, 256, 512])
    num_layers   = trial.suggest_int("num_layers", 2, 6)
    dropout      = trial.suggest_float("dropout", 0.0, 0.5)
    lr           = trial.suggest_float("lr", 1e-4, 1e-2, log=True)
    weight_decay = trial.suggest_float("weight_decay", 1e-6, 1e-3, log=True)
    batch_size   = trial.suggest_categorical("batch_size", [64, 128, 256])
    num_heads    = trial.suggest_categorical("num_heads", [2, 4, 8])

    # num_heads must divide hidden_dim (GPSConv requirement)
    if hidden_dim % num_heads != 0:
        raise optuna.TrialPruned()

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader   = DataLoader(val_dataset,   batch_size=batch_size)

    model = GPS(
        input_dim=number_of_features,
        hidden_dim=hidden_dim,
        num_layers=num_layers,
        dropout=dropout,
        num_heads=num_heads,
        pe_dim=PE_DIM,
    ).to(device)

    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    criterion = nn.BCEWithLogitsLoss()
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", factor=0.5, patience=3
    )

    n_epochs         = 50
    best_val_acc     = 0.0
    patience         = 10
    patience_counter = 0
    trial_history    = []

    for epoch in range(1, n_epochs + 1):
        train_loss = train()
        train_acc, train_f1 = test(train_loader)
        val_acc,   val_f1   = test(val_loader)

        scheduler.step(val_acc)

        trial_history.append({
            "trial":      trial.number,
            "epoch":      epoch,
            "train_loss": train_loss,
            "train_acc":  train_acc,
            "val_acc":    val_acc,
            "lr":         optimizer.param_groups[0]["lr"],
        })

        if val_acc > best_val_acc:
            best_val_acc     = val_acc
            patience_counter = 0
        else:
            patience_counter += 1

        trial.report(val_acc, epoch)

        if trial.should_prune():
            raise optuna.TrialPruned()

        if patience_counter >= patience:
            print(f"Trial {trial.number}: Early stopping at epoch {epoch}")
            break

        if epoch % 10 == 0:
            print(
                f"Trial {trial.number} | Epoch {epoch:02d} | "
                f"Train Loss: {train_loss:.4f} | "
                f"Val Acc: {val_acc:.4f}"
            )

    return best_val_acc

# %%
study = optuna.create_study(
    direction="maximize",
    pruner=optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10),
    study_name="GPS+LaplacianPE for partial automorphism extension problem",
)

study.optimize(objective, n_trials=100)

trials_df = study.trials_dataframe()
trials_df.to_csv("/kaggle/working/optuna_trials_summary.csv", index=False)

trial = study.best_trial
print(f"  Value (Val Acc): {trial.value:.4f}")
print("\n  Params: ")
for key, value in trial.params.items():
    print(f"    {key}: {value}")

best_params = study.best_params
config_path = "/kaggle/working/best_config.json"
with open(config_path, "w") as f:
    json.dump(best_params, f, indent=4)
# Out:
# [I 2026-03-23 16:01:40,564] A new study created in memory with name: GPS+LaplacianPE for partial automorphism extension problem
# Trial 0 | Epoch 10 | Train Loss: 0.4600 | Val Acc: 0.7584
# Trial 0 | Epoch 20 | Train Loss: 0.3870 | Val Acc: 0.8270
# Trial 0 | Epoch 30 | Train Loss: 0.3603 | Val Acc: 0.8450
# Trial 0 | Epoch 40 | Train Loss: 0.3077 | Val Acc: 0.8697
# [I 2026-03-23 16:12:22,389] Trial 0 finished with value: 0.8991651661483058 and parameters: {'hidden_dim': 64, 'num_layers': 3, 'dropout': 0.029227178143318044, 'lr': 0.006235975676070257, 'weight_decay': 5.631373845713581e-06, 'batch_size': 128, 'num_heads': 2}. Best is trial 0 with value: 0.8991651661483058.
# Trial 0 | Epoch 50 | Train Loss: 0.2635 | Val Acc: 0.8987
# Trial 1 | Epoch 10 | Train Loss: 0.4758 | Val Acc: 0.7843
# Trial 1 | Epoch 20 | Train Loss: 0.4555 | Val Acc: 0.7893
# Trial 1 | Epoch 30 | Train Loss: 0.4115 | Val Acc: 0.8201
# Trial 1 | Epoch 40 | Train Loss: 0.3810 | Val Acc: 0.8383
# [I 2026-03-23 16:23:02,134] Trial 1 finished with value: 0.8435095760353577 and parameters: {'hidden_dim': 256, 'num_layers': 4, 'dropout': 0.3524700977563285, 'lr': 0.002482674574426707, 'weight_decay': 0.0009514134949427544, 'batch_size': 256, 'num_heads': 4}. Best is trial 0 with value: 0.8991651661483058.
# Trial 1 | Epoch 50 | Train Loss: 0.3590 | Val Acc: 0.8435
# Trial 2 | Epoch 10 | Train Loss: 0.4393 | Val Acc: 0.7946
# Trial 2 | Epoch 20 | Train Loss: 0.3948 | Val Acc: 0.8183
# Trial 2 | Epoch 30 | Train Loss: 0.3616 | Val Acc: 0.8447
# Trial 2 | Epoch 40 | Train Loss: 0.3411 | Val Acc: 0.8528
# [I 2026-03-23 16:29:56,726] Trial 2 finished with value: 0.8631527254869864 and parameters: {'hidden_dim': 64, 'num_layers': 3, 'dropout': 0.22897384708790375, 'lr': 0.007967518625790605, 'weight_decay': 6.511242846953794e-05, 'batch_size': 256, 'num_heads': 8}. Best is trial 0 with value: 0.8991651661483058.
# Trial 2 | Epoch 50 | Train Loss: 0.3239 | Val Acc: 0.8607
# Trial 3 | Epoch 10 | Train Loss: 0.5184 | Val Acc: 0.7695
# Trial 3 | Epoch 20 | Train Loss: 0.4353 | Val Acc: 0.8090
# Trial 3 | Epoch 30 | Train Loss: 0.4066 | Val Acc: 0.8258
# Trial 3 | Epoch 40 | Train Loss: 0.3901 | Val Acc: 0.8357
# [I 2026-03-23 16:47:12,738] Trial 3 finished with value: 0.8458012768047144 and parameters: {'hidden_dim': 128, 'num_layers': 3, 'dropout': 0.35097410170987187, 'lr': 0.00010654959422637267, 'weight_decay': 0.00021968483814026966, 'batch_size': 64, 'num_heads': 2}. Best is trial 0 with value: 0.8991651661483058.
# Trial 3 | Epoch 50 | Train Loss: 0.3722 | Val Acc: 0.8458
# Trial 4 | Epoch 10 | Train Loss: 0.5038 | Val Acc: 0.7746
# Trial 4 | Epoch 20 | Train Loss: 0.4033 | Val Acc: 0.8212
# Trial 4 | Epoch 30 | Train Loss: 0.3684 | Val Acc: 0.8437
# Trial 4 | Epoch 40 | Train Loss: 0.3326 | Val Acc: 0.8605
# [I 2026-03-23 16:53:59,548] Trial 4 finished with value: 0.8765755442789327 and parameters: {'hidden_dim': 256, 'num_layers': 2, 'dropout': 0.38674963053695394, 'lr': 0.0002096884714934375, 'weight_decay': 0.0007215966221031638, 'batch_size': 256, 'num_heads': 2}. Best is trial 0 with value: 0.8991651661483058.
# Trial 4 | Epoch 50 | Train Loss: 0.3161 | Val Acc: 0.8766
# [I 2026-03-23 16:59:07,470] Trial 5 pruned.
# [I 2026-03-23 17:00:29,438] Trial 6 pruned.
# [I 2026-03-23 17:02:20,092] Trial 7 pruned.
# Trial 8 | Epoch 10 | Train Loss: 0.4025 | Val Acc: 0.8293
# Trial 8 | Epoch 20 | Train Loss: 0.3423 | Val Acc: 0.8561
# Trial 8 | Epoch 30 | Train Loss: 0.3031 | Val Acc: 0.8748
# Trial 8 | Epoch 40 | Train Loss: 0.2573 | Val Acc: 0.9075
# [I 2026-03-23 17:16:47,327] Trial 8 finished with value: 0.9192993943362252 and parameters: {'hidden_dim': 64, 'num_layers': 5, 'dropout': 0.22817245811404624, 'lr': 0.0007356085705118957, 'weight_decay': 0.00020534579445597963, 'batch_size': 128, 'num_heads': 8}. Best is trial 8 with value: 0.9192993943362252.
# Trial 8 | Epoch 50 | Train Loss: 0.2234 | Val Acc: 0.9190
# Trial 9 | Epoch 10 | Train Loss: 0.3073 | Val Acc: 0.8674
# Trial 9 | Epoch 20 | Train Loss: 0.1940 | Val Acc: 0.9049
# Trial 9 | Epoch 30 | Train Loss: 0.1330 | Val Acc: 0.9283
# Trial 9 | Epoch 40 | Train Loss: 0.0767 | Val Acc: 0.9335
# [I 2026-03-23 17:31:19,579] Trial 9 finished with value: 0.9364871501064004 and parameters: {'hidden_dim': 128, 'num_layers': 5, 'dropout': 0.034028925516043584, 'lr': 0.0001598298171326363, 'weight_decay': 1.5006789182489145e-06, 'batch_size': 128, 'num_heads': 4}. Best is trial 9 with value: 0.9364871501064004.
# Trial 9 | Epoch 50 | Train Loss: 0.0630 | Val Acc: 0.9365
# Trial 10 | Epoch 10 | Train Loss: 0.6300 | Val Acc: 0.6394
# [I 2026-03-23 17:42:12,634] Trial 10 pruned.
# Trial 11 | Epoch 10 | Train Loss: 0.4017 | Val Acc: 0.8309
# Trial 11 | Epoch 20 | Train Loss: 0.3359 | Val Acc: 0.8618
# Trial 11 | Epoch 30 | Train Loss: 0.3138 | Val Acc: 0.8713
# Trial 11 | Epoch 40 | Train Loss: 0.2782 | Val Acc: 0.8841
# [I 2026-03-23 17:58:57,368] Trial 11 finished with value: 0.8919626780160419 and parameters: {'hidden_dim': 64, 'num_layers': 6, 'dropout': 0.1667372123764362, 'lr': 0.0009163866810051962, 'weight_decay': 9.82753813412407e-05, 'batch_size': 128, 'num_heads': 8}. Best is trial 9 with value: 0.9364871501064004.
# Trial 11 | Epoch 50 | Train Loss: 0.2562 | Val Acc: 0.8892
# Trial 12 | Epoch 10 | Train Loss: 0.3942 | Val Acc: 0.8365
# Trial 12 | Epoch 20 | Train Loss: 0.3139 | Val Acc: 0.8717
# Trial 12 | Epoch 30 | Train Loss: 0.2541 | Val Acc: 0.9096
# Trial 12 | Epoch 40 | Train Loss: 0.2196 | Val Acc: 0.9185
# [I 2026-03-23 18:13:54,274] Trial 12 finished with value: 0.9265018824684891 and parameters: {'hidden_dim': 128, 'num_layers': 5, 'dropout': 0.25195320606459065, 'lr': 0.0004174179128905782, 'weight_decay': 1.0268452588971658e-06, 'batch_size': 128, 'num_heads': 8}. Best is trial 9 with value: 0.9364871501064004.
# Trial 12 | Epoch 50 | Train Loss: 0.1893 | Val Acc: 0.9239
# Trial 13 | Epoch 10 | Train Loss: 0.4283 | Val Acc: 0.8032
# [I 2026-03-23 18:17:45,461] Trial 13 pruned.
# Trial 14 | Epoch 10 | Train Loss: 0.4182 | Val Acc: 0.8319
# Trial 14 | Epoch 20 | Train Loss: 0.2960 | Val Acc: 0.8854
# Trial 14 | Epoch 30 | Train Loss: 0.2264 | Val Acc: 0.9085
# Trial 14 | Epoch 40 | Train Loss: 0.1900 | Val Acc: 0.9258
# [I 2026-03-23 18:32:22,166] Trial 14 finished with value: 0.933704370600753 and parameters: {'hidden_dim': 128, 'num_layers': 5, 'dropout': 0.09993593669817452, 'lr': 0.00011920024336514863, 'weight_decay': 1.2563799844525009e-06, 'batch_size': 128, 'num_heads': 4}. Best is trial 9 with value: 0.9364871501064004.
# Trial 14 | Epoch 50 | Train Loss: 0.1553 | Val Acc: 0.9337
# Trial 15 | Epoch 10 | Train Loss: 0.4431 | Val Acc: 0.8193
# Trial 15 | Epoch 20 | Train Loss: 0.3171 | Val Acc: 0.8718
# Trial 15 | Epoch 30 | Train Loss: 0.2567 | Val Acc: 0.8962
# Trial 15 | Epoch 40 | Train Loss: 0.2063 | Val Acc: 0.9165
# [I 2026-03-23 18:49:09,796] Trial 15 finished with value: 0.9255197249959076 and parameters: {'hidden_dim': 128, 'num_layers': 6, 'dropout': 0.10097603161904567, 'lr': 0.00010088996463605157, 'weight_decay': 6.128783457645904e-06, 'batch_size': 128, 'num_heads': 4}. Best is trial 9 with value: 0.9364871501064004.
# Trial 15 | Epoch 50 | Train Loss: 0.1738 | Val Acc: 0.9240
# Trial 16 | Epoch 10 | Train Loss: 0.3272 | Val Acc: 0.8771
# Trial 16 | Epoch 20 | Train Loss: 0.2174 | Val Acc: 0.9128
# Trial 16 | Epoch 30 | Train Loss: 0.1768 | Val Acc: 0.9254
# Trial 16 | Epoch 40 | Train Loss: 0.1446 | Val Acc: 0.9340
# [I 2026-03-23 19:19:09,466] Trial 16 finished with value: 0.9376330004910788 and parameters: {'hidden_dim': 512, 'num_layers': 4, 'dropout': 0.0747256052468491, 'lr': 0.00019080203131136293, 'weight_decay': 4.289276958374579e-06, 'batch_size': 64, 'num_heads': 4}. Best is trial 16 with value: 0.9376330004910788.
# Trial 16 | Epoch 50 | Train Loss: 0.1174 | Val Acc: 0.9350
# Trial 17 | Epoch 10 | Train Loss: 0.2840 | Val Acc: 0.8817
# Trial 17 | Epoch 20 | Train Loss: 0.3107 | Val Acc: 0.8767
# Trial 17 | Epoch 30 | Train Loss: 0.2003 | Val Acc: 0.9124
# Trial 17 | Epoch 40 | Train Loss: 0.1666 | Val Acc: 0.9270
# [I 2026-03-23 19:49:06,645] Trial 17 finished with value: 0.9294483548862335 and parameters: {'hidden_dim': 512, 'num_layers': 4, 'dropout': 0.04936820577269431, 'lr': 0.0001966609378581994, 'weight_decay': 9.577647501588801e-06, 'batch_size': 64, 'num_heads': 4}. Best is trial 16 with value: 0.9376330004910788.
# Trial 17 | Epoch 50 | Train Loss: 0.1404 | Val Acc: 0.9294
# Trial 18 | Epoch 10 | Train Loss: 0.3686 | Val Acc: 0.8479
# Trial 18 | Epoch 20 | Train Loss: 0.2897 | Val Acc: 0.8758
# Trial 18 | Epoch 30 | Train Loss: 0.2527 | Val Acc: 0.8885
# [I 2026-03-23 20:10:40,708] Trial 18 pruned.
# [I 2026-03-23 20:16:40,918] Trial 19 pruned.
# [I 2026-03-23 20:21:25,510] Trial 20 pruned.
# Trial 21 | Epoch 10 | Train Loss: 0.3974 | Val Acc: 0.8412
# Trial 21 | Epoch 20 | Train Loss: 0.2738 | Val Acc: 0.8936
# Trial 21 | Epoch 30 | Train Loss: 0.2103 | Val Acc: 0.9188
# Trial 21 | Epoch 40 | Train Loss: 0.1724 | Val Acc: 0.9275
# [I 2026-03-23 20:35:56,060] Trial 21 finished with value: 0.9369782288426911 and parameters: {'hidden_dim': 128, 'num_layers': 5, 'dropout': 0.10431277336918232, 'lr': 0.0001360393605443604, 'weight_decay': 1.7747757863021023e-06, 'batch_size': 128, 'num_heads': 4}. Best is trial 16 with value: 0.9376330004910788.
# Trial 21 | Epoch 50 | Train Loss: 0.1403 | Val Acc: 0.9357
# Trial 22 | Epoch 10 | Train Loss: 0.3997 | Val Acc: 0.8393
# Trial 22 | Epoch 20 | Train Loss: 0.3015 | Val Acc: 0.8746
# Trial 22 | Epoch 30 | Train Loss: 0.2337 | Val Acc: 0.9085
# Trial 22 | Epoch 40 | Train Loss: 0.1876 | Val Acc: 0.9224
# [I 2026-03-23 20:50:22,141] Trial 22 finished with value: 0.930266819446718 and parameters: {'hidden_dim': 128, 'num_layers': 5, 'dropout': 0.1327214782447147, 'lr': 0.00015893931206962186, 'weight_decay': 1.99406171089452e-06, 'batch_size': 128, 'num_heads': 4}. Best is trial 16 with value: 0.9376330004910788.
# Trial 22 | Epoch 50 | Train Loss: 0.1656 | Val Acc: 0.9303
# Trial 23 | Epoch 10 | Train Loss: 0.3267 | Val Acc: 0.8748
# Trial 23 | Epoch 20 | Train Loss: 0.1929 | Val Acc: 0.9201
# Trial 23 | Epoch 30 | Train Loss: 0.1477 | Val Acc: 0.9193
# Trial 23 | Epoch 40 | Train Loss: 0.1003 | Val Acc: 0.9466
# [I 2026-03-23 21:06:55,933] Trial 23 finished with value: 0.9515468980193158 and parameters: {'hidden_dim': 128, 'num_layers': 6, 'dropout': 0.07168353870927366, 'lr': 0.0002470103557698877, 'weight_decay': 1.4242092884084476e-05, 'batch_size': 128, 'num_heads': 4}. Best is trial 23 with value: 0.9515468980193158.
# Trial 23 | Epoch 50 | Train Loss: 0.0712 | Val Acc: 0.9512
# [I 2026-03-23 21:15:26,382] Trial 24 pruned.
# Trial 25 | Epoch 10 | Train Loss: 0.3266 | Val Acc: 0.8628
# Trial 25 | Epoch 20 | Train Loss: 0.2630 | Val Acc: 0.8931
# Trial 25 | Epoch 30 | Train Loss: 0.2087 | Val Acc: 0.9203
# Trial 25 | Epoch 40 | Train Loss: 0.1735 | Val Acc: 0.9288
# [I 2026-03-23 21:31:59,291] Trial 25 finished with value: 0.9310852840072025 and parameters: {'hidden_dim': 128, 'num_layers': 6, 'dropout': 0.18058744773177757, 'lr': 0.0005676755178419443, 'weight_decay': 4.3124121903529184e-05, 'batch_size': 128, 'num_heads': 4}. Best is trial 23 with value: 0.9515468980193158.
# Trial 25 | Epoch 50 | Train Loss: 0.1656 | Val Acc: 0.9304
# Trial 26 | Epoch 10 | Train Loss: 0.2471 | Val Acc: 0.9001
# Trial 26 | Epoch 20 | Train Loss: 0.1717 | Val Acc: 0.9291
# Trial 26 | Epoch 30 | Train Loss: 0.1389 | Val Acc: 0.9365
# Trial 26 | Epoch 40 | Train Loss: 0.1134 | Val Acc: 0.9447
# [I 2026-03-23 22:01:19,492] Trial 26 finished with value: 0.9558029137338353 and parameters: {'hidden_dim': 128, 'num_layers': 6, 'dropout': 0.06462332705206668, 'lr': 0.0002601918598715938, 'weight_decay': 7.227296056119813e-06, 'batch_size': 64, 'num_heads': 4}. Best is trial 26 with value: 0.9558029137338353.
# Trial 26 | Epoch 50 | Train Loss: 0.0728 | Val Acc: 0.9502
# [I 2026-03-23 22:09:49,061] Trial 27 pruned.
# Trial 28 | Epoch 10 | Train Loss: 0.3947 | Val Acc: 0.8407
# Trial 28 | Epoch 20 | Train Loss: 0.2823 | Val Acc: 0.8897
# [I 2026-03-23 22:27:13,366] Trial 28 pruned.
# Trial 29 | Epoch 10 | Train Loss: 0.2702 | Val Acc: 0.8938
# Trial 29 | Epoch 20 | Train Loss: 0.1899 | Val Acc: 0.9159
# Trial 29 | Epoch 30 | Train Loss: 0.1575 | Val Acc: 0.9286
# Trial 29 | Epoch 40 | Train Loss: 0.1129 | Val Acc: 0.9385
# [I 2026-03-23 22:44:50,092] Trial 29 finished with value: 0.942380094941889 and parameters: {'hidden_dim': 64, 'num_layers': 3, 'dropout': 0.03431070029859274, 'lr': 0.0005386968815957955, 'weight_decay': 4.005344381004336e-05, 'batch_size': 64, 'num_heads': 4}. Best is trial 26 with value: 0.9558029137338353.
# Trial 29 | Epoch 50 | Train Loss: 0.0883 | Val Acc: 0.9401
# Trial 30 | Epoch 10 | Train Loss: 0.2966 | Val Acc: 0.8753
# Trial 30 | Epoch 20 | Train Loss: 0.2462 | Val Acc: 0.8962
# Trial 30 | Epoch 30 | Train Loss: 0.1991 | Val Acc: 0.9095
# [I 2026-03-23 22:53:17,762] Trial 30 pruned.
# Trial 31 | Epoch 10 | Train Loss: 0.3449 | Val Acc: 0.8592
# Trial 31 | Epoch 20 | Train Loss: 0.2575 | Val Acc: 0.8946
# Trial 31 | Epoch 30 | Train Loss: 0.2048 | Val Acc: 0.9219
# Trial 31 | Epoch 40 | Train Loss: 0.1655 | Val Acc: 0.9326
# [I 2026-03-23 23:10:36,465] Trial 31 finished with value: 0.9350139138975282 and parameters: {'hidden_dim': 64, 'num_layers': 3, 'dropout': 0.06177251180768871, 'lr': 0.0002528334316261878, 'weight_decay': 7.799323463695447e-06, 'batch_size': 64, 'num_heads': 4}. Best is trial 26 with value: 0.9558029137338353.
# Trial 31 | Epoch 50 | Train Loss: 0.1549 | Val Acc: 0.9321
# Trial 32 | Epoch 10 | Train Loss: 0.2089 | Val Acc: 0.9111
# Trial 32 | Epoch 20 | Train Loss: 0.1354 | Val Acc: 0.9283
# Trial 32 | Epoch 30 | Train Loss: 0.0970 | Val Acc: 0.9330
# Trial 32 | Epoch 40 | Train Loss: 0.0434 | Val Acc: 0.9443
# [I 2026-03-23 23:31:55,814] Trial 32 finished with value: 0.9443444098870519 and parameters: {'hidden_dim': 64, 'num_layers': 4, 'dropout': 0.004504757432665436, 'lr': 0.0004652963235135614, 'weight_decay': 4.661219297511905e-06, 'batch_size': 64, 'num_heads': 4}. Best is trial 26 with value: 0.9558029137338353.
# Trial 32: Early stopping at epoch 50
# Trial 33 | Epoch 10 | Train Loss: 0.2069 | Val Acc: 0.9064
# Trial 33 | Epoch 20 | Train Loss: 0.1471 | Val Acc: 0.9250
# Trial 33 | Epoch 30 | Train Loss: 0.0778 | Val Acc: 0.9342
# Trial 33 | Epoch 40 | Train Loss: 0.0526 | Val Acc: 0.9352
# [I 2026-03-23 23:49:12,640] Trial 33 finished with value: 0.9374693075789818 and parameters: {'hidden_dim': 64, 'num_layers': 3, 'dropout': 0.0055507287017907, 'lr': 0.0005297264303381148, 'weight_decay': 2.983813454010625e-05, 'batch_size': 64, 'num_heads': 4}. Best is trial 26 with value: 0.9558029137338353.
# Trial 33 | Epoch 50 | Train Loss: 0.0432 | Val Acc: 0.9352
# Trial 34 | Epoch 10 | Train Loss: 0.2800 | Val Acc: 0.8831
# Trial 34 | Epoch 20 | Train Loss: 0.2032 | Val Acc: 0.9087
# Trial 34 | Epoch 30 | Train Loss: 0.1549 | Val Acc: 0.9200
# Trial 34 | Epoch 40 | Train Loss: 0.1324 | Val Acc: 0.9250
# [I 2026-03-24 00:06:37,905] Trial 34 finished with value: 0.9310852840072025 and parameters: {'hidden_dim': 64, 'num_layers': 3, 'dropout': 0.032655604416085365, 'lr': 0.00033496434256869855, 'weight_decay': 9.384021580744411e-05, 'batch_size': 64, 'num_heads': 4}. Best is trial 26 with value: 0.9558029137338353.
# Trial 34 | Epoch 50 | Train Loss: 0.1075 | Val Acc: 0.9294
# Trial 35 | Epoch 10 | Train Loss: 0.3215 | Val Acc: 0.8728
# Trial 35 | Epoch 20 | Train Loss: 0.2797 | Val Acc: 0.8988
# [I 2026-03-24 00:17:20,939] Trial 35 pruned.
# Trial 36 | Epoch 10 | Train Loss: 0.2930 | Val Acc: 0.8682
# [I 2026-03-24 00:19:35,075] Trial 36 pruned.
# Trial 37 | Epoch 10 | Train Loss: 0.3199 | Val Acc: 0.8248
# Trial 37 | Epoch 20 | Train Loss: 0.2638 | Val Acc: 0.8975
# Trial 37 | Epoch 30 | Train Loss: 0.2077 | Val Acc: 0.9204
# Trial 37 | Epoch 40 | Train Loss: 0.1715 | Val Acc: 0.9272
# [I 2026-03-24 00:37:31,477] Trial 37 finished with value: 0.9338680635128499 and parameters: {'hidden_dim': 64, 'num_layers': 3, 'dropout': 0.04114207606419767, 'lr': 0.0023594445055402516, 'weight_decay': 3.350012675302416e-06, 'batch_size': 64, 'num_heads': 4}. Best is trial 26 with value: 0.9558029137338353.
# Trial 37 | Epoch 50 | Train Loss: 0.1585 | Val Acc: 0.9327
# [I 2026-03-24 00:39:46,598] Trial 38 pruned.
# [I 2026-03-24 00:42:28,171] Trial 39 pruned.
# Trial 40 | Epoch 10 | Train Loss: 0.3738 | Val Acc: 0.8463
# [I 2026-03-24 00:47:08,446] Trial 40 pruned.
# Trial 41 | Epoch 10 | Train Loss: 0.2947 | Val Acc: 0.8743
# Trial 41 | Epoch 20 | Train Loss: 0.2015 | Val Acc: 0.9160
# Trial 41 | Epoch 30 | Train Loss: 0.1555 | Val Acc: 0.9291
# Trial 41 | Epoch 40 | Train Loss: 0.1106 | Val Acc: 0.9442
# [I 2026-03-24 01:08:31,300] Trial 41 finished with value: 0.9497462759862498 and parameters: {'hidden_dim': 128, 'num_layers': 4, 'dropout': 0.07438535943687757, 'lr': 0.00024399191356768286, 'weight_decay': 4.428360164872463e-06, 'batch_size': 64, 'num_heads': 4}. Best is trial 26 with value: 0.9558029137338353.
# Trial 41 | Epoch 50 | Train Loss: 0.0844 | Val Acc: 0.9497
# Trial 42 | Epoch 10 | Train Loss: 0.2486 | Val Acc: 0.9021
# Trial 42 | Epoch 20 | Train Loss: 0.1518 | Val Acc: 0.9344
# Trial 42 | Epoch 30 | Train Loss: 0.0907 | Val Acc: 0.9496
# Trial 42 | Epoch 40 | Train Loss: 0.0696 | Val Acc: 0.9532
# [I 2026-03-24 01:37:57,160] Trial 42 finished with value: 0.9607137010967425 and parameters: {'hidden_dim': 128, 'num_layers': 6, 'dropout': 0.050466220622879636, 'lr': 0.00026206329212839384, 'weight_decay': 5.10445179379843e-06, 'batch_size': 64, 'num_heads': 4}. Best is trial 42 with value: 0.9607137010967425.
# Trial 42 | Epoch 50 | Train Loss: 0.0396 | Val Acc: 0.9604
# Trial 43 | Epoch 10 | Train Loss: 0.2872 | Val Acc: 0.8902
# Trial 43 | Epoch 20 | Train Loss: 0.1770 | Val Acc: 0.9281
# Trial 43 | Epoch 30 | Train Loss: 0.1335 | Val Acc: 0.9457
# Trial 43 | Epoch 40 | Train Loss: 0.0849 | Val Acc: 0.9494
# [I 2026-03-24 02:07:44,109] Trial 43 finished with value: 0.9551481420854477 and parameters: {'hidden_dim': 128, 'num_layers': 6, 'dropout': 0.08204012830059759, 'lr': 0.0002471242012322378, 'weight_decay': 5.01010337421463e-06, 'batch_size': 64, 'num_heads': 4}. Best is trial 42 with value: 0.9607137010967425.
# Trial 43 | Epoch 50 | Train Loss: 0.0698 | Val Acc: 0.9529
# [I 2026-03-24 02:09:57,810] Trial 44 pruned.
# [I 2026-03-24 02:15:59,737] Trial 45 pruned.
# Trial 46 | Epoch 10 | Train Loss: 0.2751 | Val Acc: 0.8982
# Trial 46 | Epoch 20 | Train Loss: 0.1853 | Val Acc: 0.9316
# Trial 46 | Epoch 30 | Train Loss: 0.1277 | Val Acc: 0.9437
# Trial 46 | Epoch 40 | Train Loss: 0.0985 | Val Acc: 0.9455
# [I 2026-03-24 02:46:36,051] Trial 46 finished with value: 0.9495825830741529 and parameters: {'hidden_dim': 128, 'num_layers': 6, 'dropout': 0.11578830082371888, 'lr': 0.0002881989675692485, 'weight_decay': 8.862097880165957e-06, 'batch_size': 64, 'num_heads': 8}. Best is trial 42 with value: 0.9607137010967425.
# Trial 46 | Epoch 50 | Train Loss: 0.0853 | Val Acc: 0.9496
# Trial 47 | Epoch 10 | Train Loss: 0.2822 | Val Acc: 0.8929
# Trial 47 | Epoch 20 | Train Loss: 0.1939 | Val Acc: 0.9211
# Trial 47 | Epoch 30 | Train Loss: 0.1544 | Val Acc: 0.9345
# Trial 47 | Epoch 40 | Train Loss: 0.1249 | Val Acc: 0.9350
# [I 2026-03-24 03:12:15,289] Trial 47 finished with value: 0.9518742838435096 and parameters: {'hidden_dim': 128, 'num_layers': 5, 'dropout': 0.08207320694797227, 'lr': 0.0002217111093065738, 'weight_decay': 1.2767705315621163e-05, 'batch_size': 64, 'num_heads': 4}. Best is trial 42 with value: 0.9607137010967425.
# Trial 47 | Epoch 50 | Train Loss: 0.0873 | Val Acc: 0.9519
# [I 2026-03-24 03:14:08,231] Trial 48 pruned.
# [I 2026-03-24 03:17:29,254] Trial 49 pruned.
# Trial 50 | Epoch 10 | Train Loss: 0.2351 | Val Acc: 0.9069
# Trial 50 | Epoch 20 | Train Loss: 0.1639 | Val Acc: 0.9234
# Trial 50 | Epoch 30 | Train Loss: 0.0985 | Val Acc: 0.9483
# Trial 50 | Epoch 40 | Train Loss: 0.0764 | Val Acc: 0.9517
# [I 2026-03-24 03:43:07,952] Trial 50 finished with value: 0.9531838271402848 and parameters: {'hidden_dim': 128, 'num_layers': 5, 'dropout': 0.08573562798110658, 'lr': 0.00037437560766308026, 'weight_decay': 7.156026024903149e-06, 'batch_size': 64, 'num_heads': 8}. Best is trial 42 with value: 0.9607137010967425.
# Trial 50 | Epoch 50 | Train Loss: 0.0663 | Val Acc: 0.9527
# Trial 51 | Epoch 10 | Train Loss: 0.2257 | Val Acc: 0.9114
# Trial 51 | Epoch 20 | Train Loss: 0.1551 | Val Acc: 0.9286
# Trial 51 | Epoch 30 | Train Loss: 0.0927 | Val Acc: 0.9447
